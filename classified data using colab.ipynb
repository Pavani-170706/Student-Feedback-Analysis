# %%
import pandas as pd

data = pd.read_csv("student_feedback_classified (1).csv")
data.head()
# Out:
#   Department Section  Q1_Teaching effectiveness  Q2_Content Quality  \
# 0        EEE       C                          5                   2
# 1        CSE       C                          4                   4
# 2      CIVIL       A                          4                   5
# 3        EEE       C                          1                   2
# 4         IT       C                          1                   1
#
#    Q3_Classroom interaction  Q4_Resource  Q5_Overall Experience     Class
# 0                         4            1                      1  Negative
# 1                         4            3                      3   Neutral
# 2                         5            5                      2  Negative
# 3                         2            4                      5  Positive
# 4                         4            5                      2  Negative

# %%
data.columns
# Out:
# Index(['Student_Name', 'Roll_No', 'Department', 'Section',
#        'Q1_Teaching effectiveness', 'Q2_Content Quality',
#        'Q3_Classroom interaction', 'Q4_Resource', 'Q5_Overall Experience'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# Convert text columns to numbers
for col in data.columns:
    if data[col].dtype == 'object':
        data[col] = le.fit_transform(data[col])

# %%
X = data.drop("Class", axis=1)
y = data["Class"]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0
